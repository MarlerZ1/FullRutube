# %% [markdown]
# Импорт библиотек и установка устройства

# %%
# Импорт необходимых библиотек
import ffmpeg
import os
import torch
import whisper
import cv2
from PIL import Image
import pandas as pd
from transformers import (
    AutoTokenizer, AutoModelForSequenceClassification, 
    MarianMTModel, MarianTokenizer, 
    BartForConditionalGeneration, BartTokenizer, 
    BlipProcessor, BlipForConditionalGeneration
)
import re
import numpy as np
from sklearn.preprocessing import LabelEncoder
import time

# Выбор устройства для вычислений (GPU или CPU)
device = "cuda" if torch.cuda.is_available() else "cpu"

# %% [markdown]
# Загрузка моделей и токенизаторов

# %%
# Загрузка моделей и токенизаторов
whisper_model = whisper.load_model("small", device=device)  # Модель распознавания речи

translation_model = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-ru-en").to(device)
translation_tokenizer = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-ru-en")  # Модель и токенизатор для перевода с русского на английский

back_translation_model = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-en-ru").to(device)
back_translation_tokenizer = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-ru")  # Модель и токенизатор для перевода с английского на русский

summarization_model_name = 'facebook/bart-large-cnn'
summarization_model = BartForConditionalGeneration.from_pretrained(summarization_model_name).to(device)
summarization_tokenizer = BartTokenizer.from_pretrained(summarization_model_name)  # Модель и токенизатор для суммаризации текста
# Out:
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:146: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %% [markdown]
# Функция для нормализации текста

# %%
def normalize_text(text):
    """Нормализация текста: удаление пробелов и нежелательных символов"""
    text = text.strip().lower()
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^\w\s]', '', text)
    return text

# %% [markdown]
# Обработка аудио

# %%
def process_audio(video_path):
    """Обработка аудио для RuBertAudio: транскрибация, перевод и суммаризация"""
    temp_audio_path = "temp_audio.wav"
    
    try:
        # Извлечение аудио из видео
        ffmpeg.input(video_path, t=90).output(temp_audio_path, acodec='pcm_s16le', ac=1, ar='16000').run(quiet=True)
    except ffmpeg.Error as e:
        print(e.stderr.decode())
        raise

    # Транскрибация аудио
    transcript = whisper_model.transcribe(temp_audio_path)
    os.remove(temp_audio_path)

    # Перевод на английский
    english_text = translator_to_english(transcript['text'])
    # Суммаризация
    summary_english = summarize(english_text)
    # Перевод обратно на русский
    summarized_text = translate_to_russian(summary_english)

    return summarized_text

# %% [markdown]
# Функции перевода

# %%
def translator_to_english(text):
    """Перевод текста с русского на английский"""
    inputs = translation_tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
    translated = translation_model.generate(**inputs)
    return translation_tokenizer.decode(translated[0], skip_special_tokens=True)

def translate_to_russian(text):
    """Перевод текста с английского на русский"""
    inputs = back_translation_tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512).to(device)
    translated_back = back_translation_model.generate(**inputs)
    return back_translation_tokenizer.decode(translated_back[0], skip_special_tokens=True)

# %% [markdown]
# Суммаризация текста

# %%
def summarize(text):
    """Суммаризация текста"""
    inputs = summarization_tokenizer(text, return_tensors="pt", max_length=512, truncation=True).to(device)
    summary_ids = summarization_model.generate(inputs['input_ids'], max_length=300, min_length=40, length_penalty=2.0, num_beams=4, early_stopping=True)
    return summarization_tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %% [markdown]
# Обработка видео кадров

# %%
def process_video_frames(video_path):
    """Обработка видео кадров и получение текстовых описаний"""
    # Загрузка моделей для генерации описаний
    processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
    caption_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")
    caption_model.to(device)

    # Извлечение и обработка кадров видео
    frames = extract_frames(video_path)
    captions = generate_captions(frames, processor, caption_model, device)
    combined_text = ", ".join(captions)

    # Суммаризация и перевод описаний
    summarized_text = summarize(combined_text)
    translated_description = translate_to_russian(summarized_text)

    return translated_description

# %% [markdown]
# Извлечение и обработка кадров

# %%
def extract_frames(video_path, num_frames=16):
    """Извлечение кадров из видео"""
    vidcap = cv2.VideoCapture(video_path)
    frames = []
    total_frames = int(vidcap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_interval = max(total_frames // num_frames, 1)
    success, image = vidcap.read()
    count = 0
    while success and len(frames) < num_frames:
        if count % frame_interval == 0:
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            frames.append(Image.fromarray(image_rgb))
        success, image = vidcap.read()
        count += 1
    vidcap.release()
    return frames

def generate_captions(frames, processor, model, device):
    """Генерация описаний для каждого из кадров"""
    captions = []
    unique_captions = set()
    inputs = processor(images=frames, return_tensors="pt", padding=True).to(device)
    with torch.no_grad():
        outputs = model.generate(**inputs, max_length=30, num_beams=5, early_stopping=True)
    for output in outputs:
        caption = processor.decode(output, skip_special_tokens=True)
        if caption not in unique_captions:
            unique_captions.add(caption)
            captions.append(caption)
    return captions

# %% [markdown]
# Предсказание тегов

# %%
def predict_tags(model_path, input_text, top_n=3, min_confidence=0.1):
    """Предсказание тегов с выводом самых уверенных, выше порога min_confidence"""
    # Загрузка модели и токенизатора
    model = AutoModelForSequenceClassification.from_pretrained(model_path)
    tokenizer = AutoTokenizer.from_pretrained(model_path)
    model.to(device)

    # Нормализация и токенизация текста
    normalized_text = normalize_text(input_text)  # Убедитесь, что эта функция определена
    encoding = tokenizer(normalized_text, return_tensors='pt', truncation=True, padding=True, max_length=256)
    encoding = {k: v.to(device) for k, v in encoding.items()}

    # Предсказание
    with torch.no_grad():
        outputs = model(**encoding)
        probabilities = torch.nn.functional.softmax(outputs.logits, dim=-1)

    # Загрузка кодировщика меток
    label_encoder = LabelEncoder()
    label_encoder.classes_ = np.load(os.path.join(model_path, 'label_encoder_classes.npy'), allow_pickle=True)

    # Получение топовых тегов, выше порога вероятности
    top_probs, top_indices = torch.topk(probabilities, top_n, dim=1)
    tags_with_probs = [(label_encoder.inverse_transform([idx.item()])[0], prob.item()) 
                       for prob, idx in zip(top_probs[0], top_indices[0]) if prob.item() > min_confidence]

    return tags_with_probs

# %%
from collections import defaultdict

def combine_and_select_top_tags(text_tags, audio_tags, video_tags, top_n=5):
    """Объединение и выбор самых уверенных тегов от трех различных моделей, без повторений"""
    
    # Объединение всех тегов в один список
    all_tags = text_tags + audio_tags + video_tags
    
    # Используем словарь для хранения максимальной уверенности для каждого тега
    tag_confidence = defaultdict(lambda: 0)

    # Обновляем словарь, сохраняя максимальную уверенность для каждого тега
    for tag, accuracy in all_tags:
        if accuracy > tag_confidence[tag]:
            tag_confidence[tag] = accuracy

    # Преобразуем в список и сортируем по убыванию уверенности
    sorted_tags = sorted(tag_confidence.items(), key=lambda item: item[1], reverse=True)
    
    # Выбираем топ-N наиболее уверенных тегов
    most_confident_tags = sorted_tags[:top_n]

    # Выводим наиболее уверенные теги и их точность
    print("Наиболее уверенные теги и их точность:")
    for tag, accuracy in most_confident_tags:
        print(f"{tag}: {accuracy:.2f}")

    return most_confident_tags

# %%
import os
import pandas as pd
import time

def process_csv(input_csv_path, output_csv_path, videos_path, use_text=True, use_audio=True, use_video=True):
    """Обработка CSV файла и запись обновленного файла с предсказанными тегами"""

    # Чтение CSV файла
    df = pd.read_csv(input_csv_path)
    if os.path.exists(output_csv_path):
        processed_df = pd.read_csv(output_csv_path)
        processed_videos = set(processed_df['video_id'])
    else:
        processed_videos = set()

    total_videos = len(df)

    # Итерация по каждой строке CSV файла
    for index, row in df.iterrows():
        video_id = row['video_id']
        
        if video_id in processed_videos:
            print(f"Video {video_id} already processed. Skipping...")
            continue
        
        title = row['title']
        description = row['description']
        
        # Создание пути к видео файлу
        video_file_path = os.path.join(videos_path, f"{video_id}.mp4")
        print(f"Processing video {index + 1}/{total_videos}: {video_file_path}")

        start_time = time.time()

        # Определяем списки тегов для каждой модели
        text_tags, audio_tags, video_tags = [], [], []

        # Запуск анализа текста
        if use_text:
            combined_text = f"{title} {description}"
            text_tags = predict_tags("RuBertText/saved_model", combined_text)

        # Запуск анализа аудио
        if use_audio:
            summarized_audio_text = process_audio(video_file_path)
            audio_tags = predict_tags("RuBertAudio/saved_model", summarized_audio_text)

        # Запуск анализа видео
        if use_video:
            translated_video_description = process_video_frames(video_file_path)
            video_tags = predict_tags("RuBertVideo/saved_model", translated_video_description)

        # Объединение и выбор самых уверенных тегов
        most_confident_tags = combine_and_select_top_tags(text_tags, audio_tags, video_tags, top_n=3)
        
        # Преобразование тегов в формат кортежей
        predicted_tags = [(str(tag),) for tag, _ in most_confident_tags]

        # Подготовка результата для добавления
        result = {'video_id': video_id, 'predicted_tags': predicted_tags}

        # Открытие и добавление результата в CSV файл
        with open(output_csv_path, 'a') as f:
            result_df = pd.DataFrame([result])
            result_df.to_csv(f, header=f.tell()==0, index=False)

        end_time = time.time()
        print(f"Processed video {video_id} in {end_time - start_time:.2f} seconds. Remaining: {total_videos - (index + 1)} videos.")

# %% [markdown]
# Основная логика выполнения

# %%
def main(video_path, title, description):
    """Основная функция для обработки видео и получения тегов.
       Возвращает текстовые, аудио и видео теги."""
    
    # Обработка текста
    print("Processing text...")
    combined_text = f"{title} {description}"
    text_tags = predict_tags("RuBertText/saved_model", combined_text)
    print("Text model tags:", text_tags)

    # Обработка аудио
    print("Processing audio...")
    summarized_audio_text = process_audio(video_path)
    audio_tags = predict_tags("RuBertAudio/saved_model", summarized_audio_text)
    print("Audio model tags:", audio_tags)

    # Обработка видео
    print("Processing video frames...")
    translated_video_description = process_video_frames(video_path)
    video_tags = predict_tags("RuBertVideo/saved_model", translated_video_description)
    print("Video model tags:", video_tags)

    # Возврат тегов
    return text_tags, audio_tags, video_tags

# %% [markdown]
# Запуск основного метода

# %%
# Пример использования
input_csv_path = "/home/user1/hak/video/test_tag_video (2)/sample_submission.csv"
output_csv_path = "/home/user1/hak/video/test_tag_video (2)/updated_submission.csv"
videos_path = "/home/user1/hak/video/test_tag_video (2)/videos"

process_csv(input_csv_path, output_csv_path, videos_path, use_text=True, use_audio=False, use_video=False)
# Out:
# Processing video 1/199: /home/user1/hak/video/test_tag_video (2)/videos/c00d1b173ed8680c155b773d43af7791.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.91
# Processed video c00d1b173ed8680c155b773d43af7791 in 0.47 seconds. Remaining: 198 videos.
# Processing video 2/199: /home/user1/hak/video/test_tag_video (2)/videos/6064c4511a067f2e1d1cef81c21421e8.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.64
# Processed video 6064c4511a067f2e1d1cef81c21421e8 in 0.45 seconds. Remaining: 197 videos.
# Processing video 3/199: /home/user1/hak/video/test_tag_video (2)/videos/3071e2054a02a03150463e514f05fe90.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.76
# Processed video 3071e2054a02a03150463e514f05fe90 in 0.45 seconds. Remaining: 196 videos.
# Processing video 4/199: /home/user1/hak/video/test_tag_video (2)/videos/60867179613376c8b56f0705114a7685.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.26
# Транспорт: 0.13
# Processed video 60867179613376c8b56f0705114a7685 in 0.46 seconds. Remaining: 195 videos.
# Processing video 5/199: /home/user1/hak/video/test_tag_video (2)/videos/706f44ef4711eaee99035260c2d1ab86.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.94
# Processed video 706f44ef4711eaee99035260c2d1ab86 in 0.46 seconds. Remaining: 194 videos.
# Processing video 6/199: /home/user1/hak/video/test_tag_video (2)/videos/b0941e302f926787c6cb61ff5a166ff1.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.84
# Processed video b0941e302f926787c6cb61ff5a166ff1 in 0.45 seconds. Remaining: 193 videos.
# Processing video 7/199: /home/user1/hak/video/test_tag_video (2)/videos/e0a3fae1b33c2bcf96efc97e8f0a68c0.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.28
# Processed video e0a3fae1b33c2bcf96efc97e8f0a68c0 in 0.45 seconds. Remaining: 192 videos.
# Processing video 8/199: /home/user1/hak/video/test_tag_video (2)/videos/90ea0fe1d949031b08366985cd65f53d.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.18
# Processed video 90ea0fe1d949031b08366985cd65f53d in 0.46 seconds. Remaining: 191 videos.
# Processing video 9/199: /home/user1/hak/video/test_tag_video (2)/videos/70eb088d65994b8cfd1be8d1349b7ad1.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video 70eb088d65994b8cfd1be8d1349b7ad1 in 0.45 seconds. Remaining: 190 videos.
# Processing video 10/199: /home/user1/hak/video/test_tag_video (2)/videos/b13e8b5a9490bc0777d4ac895e8e46f8.mp4
# Наиболее уверенные теги и их точность:
# Processed video b13e8b5a9490bc0777d4ac895e8e46f8 in 0.45 seconds. Remaining: 189 videos.
# Processing video 11/199: /home/user1/hak/video/test_tag_video (2)/videos/e1752df306182c86be1610004c816744.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.32
# Processed video e1752df306182c86be1610004c816744 in 0.45 seconds. Remaining: 188 videos.
# Processing video 12/199: /home/user1/hak/video/test_tag_video (2)/videos/8171c9eb5415db1ab4b9f99ffcbe7d6f.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.25
# Транспорт: 0.15
# Processed video 8171c9eb5415db1ab4b9f99ffcbe7d6f in 0.45 seconds. Remaining: 187 videos.
# Processing video 13/199: /home/user1/hak/video/test_tag_video (2)/videos/e17e3bf022a56da3b5e057439f64bbb2.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.77
# Processed video e17e3bf022a56da3b5e057439f64bbb2 in 0.46 seconds. Remaining: 186 videos.
# Processing video 14/199: /home/user1/hak/video/test_tag_video (2)/videos/61aa755125f71f3e5a80b8bbd9eb67f8.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.25
# Транспорт: 0.15
# Processed video 61aa755125f71f3e5a80b8bbd9eb67f8 in 0.47 seconds. Remaining: 185 videos.
# Processing video 15/199: /home/user1/hak/video/test_tag_video (2)/videos/81b39b129e9c23d6ddb865bf153dd5ea.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0
mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video f59cef287bd3084cd13e7fca0002f624 in 0.45 seconds. Remaining: 129 videos.
# Processing video 71/199: /home/user1/hak/video/test_tag_video (2)/videos/e5971a9caa7348e8e5892af6fb3483c3.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.75
# Processed video e5971a9caa7348e8e5892af6fb3483c3 in 0.46 seconds. Remaining: 128 videos.
# Processing video 72/199: /home/user1/hak/video/test_tag_video (2)/videos/15db6242726087b5089243346331b590.mp4
# Наиболее уверенные теги и их точность:
# Спорт: Борьба: 0.13
# Processed video 15db6242726087b5089243346331b590 in 0.46 seconds. Remaining: 127 videos.
# Processing video 73/199: /home/user1/hak/video/test_tag_video (2)/videos/75b78216cbd27bf079274c3fd0ae6ec9.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.33
# Транспорт: 0.11
# Processed video 75b78216cbd27bf079274c3fd0ae6ec9 in 0.46 seconds. Remaining: 126 videos.
# Processing video 74/199: /home/user1/hak/video/test_tag_video (2)/videos/25cf8f45adc75b7d698dbd578fccb909.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.15
# Processed video 25cf8f45adc75b7d698dbd578fccb909 in 0.46 seconds. Remaining: 125 videos.
# Processing video 75/199: /home/user1/hak/video/test_tag_video (2)/videos/361377087b3cd121e0c5cec74e0ed24f.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.74
# Processed video 361377087b3cd121e0c5cec74e0ed24f in 0.47 seconds. Remaining: 124 videos.
# Processing video 76/199: /home/user1/hak/video/test_tag_video (2)/videos/f5f9ec71166218c6d74ffbd9bb081ec3.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video f5f9ec71166218c6d74ffbd9bb081ec3 in 0.46 seconds. Remaining: 123 videos.
# Processing video 77/199: /home/user1/hak/video/test_tag_video (2)/videos/165fe4fd370ec4a27965370dc07690b5.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.83
# Processed video 165fe4fd370ec4a27965370dc07690b5 in 0.46 seconds. Remaining: 122 videos.
# Processing video 78/199: /home/user1/hak/video/test_tag_video (2)/videos/867f29bc176c8b011a4bb698204421ad.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.10
# Processed video 867f29bc176c8b011a4bb698204421ad in 0.46 seconds. Remaining: 121 videos.
# Processing video 79/199: /home/user1/hak/video/test_tag_video (2)/videos/b6930de082f29972814843065668a7ef.mp4
# Наиболее уверенные теги и их точность:
# Дом и сад: Дизайн интерьера: 0.16
# Processed video b6930de082f29972814843065668a7ef in 0.46 seconds. Remaining: 120 videos.
# Processing video 80/199: /home/user1/hak/video/test_tag_video (2)/videos/8690d2ad3832f42d76c1d281b6c268ac.mp4
# Наиболее уверенные теги и их точность:
# Processed video 8690d2ad3832f42d76c1d281b6c268ac in 0.46 seconds. Remaining: 119 videos.
# Processing video 81/199: /home/user1/hak/video/test_tag_video (2)/videos/e64b4959d5cee7f0ebf0496474cb7ad0.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.41
# Processed video e64b4959d5cee7f0ebf0496474cb7ad0 in 0.46 seconds. Remaining: 118 videos.
# Processing video 82/199: /home/user1/hak/video/test_tag_video (2)/videos/f6535dbbc77f80f11e4c6d3702410449.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.81
# Processed video f6535dbbc77f80f11e4c6d3702410449 in 0.46 seconds. Remaining: 117 videos.
# Processing video 83/199: /home/user1/hak/video/test_tag_video (2)/videos/76562f46b286a03979696d243972ffa9.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.19
# Путешествия: 0.13
# Processed video 76562f46b286a03979696d243972ffa9 in 0.46 seconds. Remaining: 116 videos.
# Processing video 84/199: /home/user1/hak/video/test_tag_video (2)/videos/f661e71761b22ff66aaa1255c567337e.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.78
# Processed video f661e71761b22ff66aaa1255c567337e in 0.46 seconds. Remaining: 115 videos.
# Processing video 85/199: /home/user1/hak/video/test_tag_video (2)/videos/16cf70cb580064f171dd7cfb45dde8af.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.29
# Processed video 16cf70cb580064f171dd7cfb45dde8af in 0.46 seconds. Remaining: 114 videos.
# Processing video 86/199: /home/user1/hak/video/test_tag_video (2)/videos/56cef9e342a321f4a034838f450d54c2.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.69
# Processed video 56cef9e342a321f4a034838f450d54c2 in 0.46 seconds. Remaining: 113 videos.
# Processing video 87/199: /home/user1/hak/video/test_tag_video (2)/videos/46b4c4fb4b8a7f0f61c0f03ab9bdf93c.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.72
# Processed video 46b4c4fb4b8a7f0f61c0f03ab9bdf93c in 0.46 seconds. Remaining: 112 videos.
# Processing video 88/199: /home/user1/hak/video/test_tag_video (2)/videos/370f9c559d9703abcc3941784a71e659.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.76
# Processed video 370f9c559d9703abcc3941784a71e659 in 0.46 seconds. Remaining: 111 videos.
# Processing video 89/199: /home/user1/hak/video/test_tag_video (2)/videos/a6eed12d4d5e3cee847d55f7ad1355af.mp4
# Наиболее уверенные теги и их точность:
# Processed video a6eed12d4d5e3cee847d55f7ad1355af in 0.46 seconds. Remaining: 110 videos.
# Processing video 90/199: /home/user1/hak/video/test_tag_video (2)/videos/26c5688b87fefbabfa3b43dcdcab6a21.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.56
# Processed video 26c5688b87fefbabfa3b43dcdcab6a21 in 0.46 seconds. Remaining: 109 videos.
# Processing video 91/199: /home/user1/hak/video/test_tag_video (2)/videos/c724e766dccfd54da9ad1a01885f81c0.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.58
# Processed video c724e766dccfd54da9ad1a01885f81c0 in 0.46 seconds. Remaining: 108 videos.
# Processing video 92/199: /home/user1/hak/video/test_tag_video (2)/videos/97112984d4fab00cddd2e0e32093f92a.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.86
# Processed video 97112984d4fab00cddd2e0e32093f92a in 0.46 seconds. Remaining: 107 videos.
# Processing video 93/199: /home/user1/hak/video/test_tag_video (2)/videos/46ea04be096efb850439e1cc1063287d.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.57
# Processed video 46ea04be096efb850439e1cc1063287d in 0.45 seconds. Remaining: 106 videos.
# Processing video 94/199: /home/user1/hak/video/test_tag_video (2)/videos/972150c4e89ccb4daa94f2d24861550d.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.86
# Processed video 972150c4e89ccb4daa94f2d24861550d in 0.45 seconds. Remaining: 105 videos.
# Processing video 95/199: /home/user1/hak/video/test_tag_video (2)/videos/26e5734c3dc1e121297e2d0e7e53dd60.mp4
# Наиболее уверенные теги и их точность:
# Спорт: Борьба: 0.13
# Processed video 26e5734c3dc1e121297e2d0e7e53dd60 in 0.46 seconds. Remaining: 104 videos.
# Processing video 96/199: /home/user1/hak/video/test_tag_video (2)/videos/f70f9d7ff562fd6ce75e61f05aabf735.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.44
# Processed video f70f9d7ff562fd6ce75e61f05aabf735 in 0.46 seconds. Remaining: 103 videos.
# Processing video 97/199: /home/user1/hak/video/test_tag_video (2)/videos/674f1327cafe0afbba500233f940d5d3.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.82
# Processed video 674f1327cafe0afbba500233f940d5d3 in 0.46 seconds. Remaining: 102 videos.
# Processing video 98/199: /home/user1/hak/video/test_tag_video (2)/videos/e76970fd62fdd82f2d90391a07238ffc.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.84
# Processed video e76970fd62fdd82f2d90391a07238ffc in 0.46 seconds. Remaining: 101 videos.
# Processing video 99/199: /home/user1/hak/video/test_tag_video (2)/videos/37ce26e81a626f67824d47e748e1097d.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.79
# Processed video 37ce26e81a626f67824d47e748e1097d in 0.46 seconds. Remaining: 100 videos.
# Processing video 100/199: /home/user1/hak/video/test_tag_video (2)/videos/e7a6c037a5ee944f73a77f7f61543aae.mp4
# Наиболее уверенные теги и их точность:
# Processed video e7a6c037a5ee944f73a77f7f61543aae in 0.46 seconds. Remaining: 99 videos.
# Processing video 101/199: /home/user1/hak/video/test_tag_video (2)/videos/07f0db83e38fff3b6f4fe8527ff25039.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.83
# Processed video 07f0db83e38fff3b6f4fe8527ff25039 in 0.46 seconds. Remaining: 98 videos.
# Processing video 102/199: /home/user1/hak/video/test_tag_video (2)/videos/882b97ebba764900f77462777cbf5ce1.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.86
# Processed video 882b97ebba764900f77462777cbf5ce1 in 0.46 seconds. Remaining: 97 videos.
# Processing video 103/199: /home/user1/hak/video/test_tag_video (2)/videos/581c8ff5516110081721bec99bc71ba8.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.20
# Транспорт: 0.16
# Processed video 581c8ff5516110081721bec99bc71ba8 in 0.46 seconds. Remaining: 96 videos.
# Processing video 104/199: /home/user1/hak/video/test_tag_video (2)/videos/083492709d578d030e17e8bdeddb34ea.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.94
# Processed video 083492709d578d030e17e8bdeddb34ea in 0.46 seconds. Remaining: 95 videos.
# Processing video 105/199: /home/user1/hak/video/test_tag_video (2)/videos/f823b1d0a23883ea2248990921d1a182.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.58
# Processed video f823b1d0a23883ea2248990921d1a182 in 0.46 seconds. Remaining: 94 videos.
# Processing video 106/199: /home/user1/hak/video/test_tag_video (2)/videos/282c79f79a471202c8ddac397c1cc8a1.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.12
# Processed video 282c79f79a471202c8ddac397c1cc8a1 in 0.46 seconds. Remaining: 93 videos.
# Processing video 107/199: /home/user1/hak/video/test_tag_video (2)/videos/3881e283eba9b8e719d6171bc44ee84e.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.52
# Processed video 3881e283eba9b8e719d6171bc44ee84e in 0.46 seconds. Remaining: 92 videos.
# Processing video 108/199: /home/user1/hak/video/test_tag_video (2)/videos/4885397a91b4e3ee020ece18ef8a8786.mp4
# Наиболее уверенные теги и их точность:
# Processed video 4885397a91b4e3ee020ece18ef8a8786 in 0.46 seconds. Remaining: 91 videos.
# Processing video 109/199: /home/user1/hak/video/test_tag_video (2)/videos/d8f7d4ce5c37e725dc47d634a4115011.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.13
# Processed video d8f7d4ce5c37e725dc47d634a4115011 in 0.46 seconds. Remaining: 90 videos.
# Processing video 110/199: /home/user1/hak/video/test_tag_video (2)/videos/1902e27a8d546b96175f9ee2f4470e65.mp4
# Наиболее уверенные теги и их точность:
# Спорт: Рыбалка: 0.19
# Processed video 1902e27a8d546b96175f9ee2f4470e65 in 0.46 seconds. Remaining: 89 videos.
# Processing video 111/199: /home/user1/hak/video/test_tag_video (2)/videos/c93eefa6c1062f7ba7552502bbb71f7d.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.36
# Processed video c93eefa6c1062f7ba7552502bbb71f7d in 0.45 seconds. Remaining: 88 videos.
# Processing video 112/199: /home/user1/hak/video/test_tag_video (2)/videos/e8c596ce996946ca121795fc53f0480b.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video e8c596ce996946ca121795fc53f0480b in 0.46 seconds. Remaining: 87 videos.
# Processing video 113/199: /home/user1/hak/video/test_tag_video (2)/videos/c95ba3fd9c94a50fcec2a650dd941a89.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.74
# Processed video c95ba3fd9c94a50fcec2a650dd941a89 in 0.46 seconds. Remaining: 86 videos.
# Processing video 114/199: /home/user1/hak/video/test_tag_video (2)/videos/092a79e1e001f736ddf3433000b27f19.mp4
# Наиболее уверенные теги и их точность:
# Processed video 092a79e1e001f736ddf3433000b27f19 in 0.46 seconds. Remaining: 85 videos.
# Processing video 115/199: /home/user1/hak/video/test_tag_video (2)/videos/89697674610449124930370d907c2099.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.87
# Processed video 89697674610449124930370d907c2099 in 0.46 seconds. Remaining: 84 videos.
# Processing video 116/199: /home/user1/hak/video/test_tag_video (2)/videos/f8f5e2cbf7d0638347b743a995d74ea6.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.29
# Транспорт: 0.12
# Processed video f8f5e2cbf7d0638347b743a995d74ea6 in 0.46 seconds. Remaining: 83 videos.
# Processing video 117/199: /home/user1/hak/video/test_tag_video (2)/videos/a977cfae174034f03774861f9b4afc94.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.29
# Транспорт: 0.12
# Processed video a977cfae174034f03774861f9b4afc94 in 0.46 seconds. Remaining: 82 videos.
# Processing video 118/199: /home/user1/hak/video/test_tag_video (2)/videos/a989141fa40a039593a89d54cdfff410.mp4
# Наиболее уверенные теги и их точность:
# Дом и сад: Дизайн интерьера: 0.15
# Processed video a989141fa40a039593a89d54cdfff410 in 0.46 seconds. Remaining: 81 videos.
# Processing video 119/199: /home/user1/hak/video/test_tag_video (2)/videos/a99e0b0fc272640a1ebcd23e8ff3589d.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.28
# Массовая культура: Юмор и сатира: 0.24
# Processed video a99e0b0fc272640a1ebcd23e8ff3589d in 0.46 seconds. Remaining: 80 videos.
# Processing video 120/199: /home/user1/hak/video/test_tag_video (2)/videos/99aea4f594ad0452528a03aebe60efc9.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.20
# Транспорт: 0.16
# Processed video 99aea4f594ad0452528a03aebe60efc9 in 0.45 seconds. Remaining: 79 videos.
# Processing video 121/199: /home/user1/hak/video/test_tag_video (2)/videos/99d1ceabed2eb23d1cf2c756d73351c0.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.58
# Processed video 99d1ceabed2eb23d1cf2c756d73351c0 in 0.46 seconds. Remaining: 78 videos.
# Processing video 122/199: /home/user1/hak/video/test_tag_video (2)/videos/798813e0fc976f15add2da740afe963c.mp4
# Наиболее уверенные теги и их точность:
# Processed video 798813e0fc976f15add2da740afe963c in 0.46 seconds. Remaining: 77 videos.
# Processing video 123/199: /home/user1/hak/video/test_tag_video (2)/videos/f9990335b45314938c396c40f6ff9bd0.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.19
# Транспорт: 0.16
# Processed video f9990335b45314938c396c40f6ff9bd0 in 0.46 seconds. Remaining: 76 videos.
# Processing video 124/199: /home/user1/hak/video/test_tag_video (2)/videos/69d14f440243202ec3b95b6f5612eca4.mp4
# Наиболее уверенные теги и их точность:
# Processed video 69d14f440243202ec3b95b6f5612eca4 in 0.46 seconds. Remaining: 75 videos.
# Processing video 125/199: /home/user1/hak/video/test_tag_video (2)/videos/e9d01a43a289b4866a1e530f3ff45486.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video e9d01a43a289b4866a1e530f3ff45486 in 0.46 seconds. Remaining: 74 videos.
# Processing video 126/199: /home/user1/hak/video/test_tag_video (2)/videos/8a587c1ccd04c1922cc358ee503542dd.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.88
# Processed video 8a587c1ccd04c1922cc358ee503542dd in 0.46 seconds. Remaining: 73 videos.
# Processing video 127/199: /home/user1/hak/video/test_tag_video (2)/videos/da6700408052d8790d2beaf2158574e1.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.57
# Processed video da6700408052d8790d2beaf2158574e1 in 0.46 seconds. Remaining: 72 videos.
# Processing video 128/199: /home/user1/hak/video/test_tag_video (2)/videos/aa5a0d3617106a88521bdb65f9787676.mp4
# Наиболее уверенные теги и их точность:
# Processed video aa5a0d3617106a88521bdb65f9787676 in 0.46 seconds. Remaining: 71 videos.
# Processing video 129/199: /home/user1/hak/video/test_tag_video (2)/videos/9a96b1834ff3fc25c3d37fadfb8ca3fc.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.28
# Processed video 9a96b1834ff3fc25c3d37fadfb8ca3fc in 0.46 seconds. Remaining: 70 videos.
# Processing video 130/199: /home/user1/hak/video/test_tag_video (2)/videos/3a3e2b4631167075381ae6324f539f34.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.42
# Processed video 3a3e2b4631167075381ae6324f539f34 in 0.46 seconds. Remaining: 69 videos.
# Processing video 131/199: /home/user1/hak/video/test_tag_video (2)/videos/6a32df072f15104386618235d0d302b3.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.92
# Processed video 6a32df072f15104386618235d0d302b3 in 0.46 seconds. Remaining: 68 videos.
# Processing video 132/199: /home/user1/hak/video/test_tag_video (2)/videos/1ab5b5f3d12507435efc2e5253339f30.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.61
# Processed video 1ab5b5f3d12507435efc2e5253339f30 in 0.46 seconds. Remaining: 67 videos.
# Processing video 133/199: /home/user1/hak/video/test_tag_video (2)/videos/3aa072ba5fdb28060119d7acc946f835.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video 3aa072ba5fdb28060119d7acc946f835 in 0.46 seconds. Remaining: 66 videos.
# Processing video 134/199: /home/user1/hak/video/test_tag_video (2)/videos/dafb9f1c3854f229fab21115480e6d15.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.60
# Processed video dafb9f1c3854f229fab21115480e6d15 in 0.47 seconds. Remaining: 65 videos.
# Processing video 135/199: /home/user1/hak/video/test_tag_video (2)/videos/eaa6023c8cb5f4caf3e142e3f17b386e.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.59
# Processed video eaa6023c8cb5f4caf3e142e3f17b386e in 0.48 seconds. Remaining: 64 videos.
# Processing video 136/199: /home/user1/hak/video/test_tag_video (2)/videos/4af24038f57110ab20d3fb4af4ec3229.mp4
# Наиболее уверенные теги и их точность:
# Processed video 4af24038f57110ab20d3fb4af4ec3229 in 0.48 seconds. Remaining: 63 videos.
# Processing video 137/199: /home/user1/hak/video/test_tag_video (2)/videos/2b2223b7f5f0b357654daa62153b92cc.mp4
# Наиболее уверенные теги и их точность:
# Processed video 2b2223b7f5f0b357654daa62153b92cc in 0.48 seconds. Remaining: 62 videos.
# Processing video 138/199: /home/user1/hak/video/test_tag_video (2)/videos/fb107476f8be3871ddd2a812b5e3e4f5.mp4
# Наиболее уверенные теги и их точность:
# Processed video fb107476f8be3871ddd2a812b5e3e4f5 in 0.47 seconds. Remaining: 61 videos.
# Processing video 139/199: /home/user1/hak/video/test_tag_video (2)/videos/2b2bd2e70854a4589ec03d48946c639b.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.27
# Массовая культура: 0.16
# Processed video 2b2bd2e70854a4589ec03d48946c639b in 0.47 seconds. Remaining: 60 videos.
# Processing video 140/199: /home/user1/hak/video/test_tag_video (2)/videos/8bcecf4a9f450e0f7458f04be25f0bd8.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video 8bcecf4a9f450e0f7458f04be25f0bd8 in 0.85 seconds. Remaining: 59 videos.
# Processing video 141/199: /home/user1/hak/video/test_tag_video (2)/videos/7b7bad1203c4dd9d6705a303f0183f8c.mp4
# Наиболее уверенные теги и их точность:
# Processed video 7b7bad1203c4dd9d6705a303f0183f8c in 0.49 seconds. Remaining: 58 videos.
# Processing video 142/199: /home/user1/hak/video/test_tag_video (2)/videos/3ba7044f68bdb86bb38d56aad3340456.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video 3ba7044f68bdb86bb38d56aad3340456 in 0.47 seconds. Remaining: 57 videos.
# Processing video 143/199: /home/user1/hak/video/test_tag_video (2)/videos/abd30314f7cc0294ee1eb9326db8c457.mp4
# Наиболее уверенные теги и их точность:
# Processed video abd30314f7cc0294ee1eb9326db8c457 in 0.46 seconds. Remaining: 56 videos.
# Processing video 144/199: /home/user1/hak/video/test_tag_video (2)/videos/cc0904d3de995d4851de65b93860d8d5.mp4
# Наиболее уверенные теги и их точность:
# Спорт: Рыбалка: 0.17
# Processed video cc0904d3de995d4851de65b93860d8d5 in 0.46 seconds. Remaining: 55 videos.
# Processing video 145/199: /home/user1/hak/video/test_tag_video (2)/videos/eba99715faabb18115f82bcd6029d838.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.25
# Транспорт: 0.14
# Processed video eba99715faabb18115f82bcd6029d838 in 0.47 seconds. Remaining: 54 videos.
# Processing video 146/199: /home/user1/hak/video/test_tag_video (2)/videos/1bd82a1ed60a2733aec953b49e94efe9.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.67
# Processed video 1bd82a1ed60a2733aec953b49e94efe9 in 0.46 seconds. Remaining: 53 videos.
# Processing video 147/199: /home/user1/hak/video/test_tag_video (2)/videos/2ba05ee68bdb2cf15a70a32c6a5b12cc.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.22
# Транспорт: 0.16
# Processed video 2ba05ee68bdb2cf15a70a32c6a5b12cc in 0.46 seconds. Remaining: 52 videos.
# Processing video 148/199: /home/user1/hak/video/test_tag_video (2)/videos/0c067ba61ca3b78bd5de778774bf8ade.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.76
# Processed video 0c067ba61ca3b78bd5de778774bf8ade in 0.46 seconds. Remaining: 51 videos.
# Processing video 149/199: /home/user1/hak/video/test_tag_video (2)/videos/9c528ce9ac3d25999ce79940ba3ebc8a.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.31
# Транспорт: 0.12
# Processed video 9c528ce9ac3d25999ce79940ba3ebc8a in 0.47 seconds. Remaining: 50 videos.
# Processing video 150/199: /home/user1/hak/video/test_tag_video (2)/videos/bc3e93908fe4a16b4a40b29a3f2bb727.mp4
# Наиболее уверенные теги и их точность:
# Processed video bc3e93908fe4a16b4a40b29a3f2bb727 in 0.47 seconds. Remaining: 49 videos.
# Processing video 151/199: /home/user1/hak/video/test_tag_video (2)/videos/ac3f9d3784bc09586ad06f1ba23d7c0a.mp4
# Наиболее уверенные теги и их точность:
# Дом и сад: Дизайн интерьера: 0.11
# Processed video ac3f9d3784bc09586ad06f1ba23d7c0a in 0.46 seconds. Remaining: 48 videos.
# Processing video 152/199: /home/user1/hak/video/test_tag_video (2)/videos/9c60bf6f920c74c983d24516c16a106b.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.59
# Processed video 9c60bf6f920c74c983d24516c16a106b in 0.47 seconds. Remaining: 47 videos.
# Processing video 153/199: /home/user1/hak/video/test_tag_video (2)/videos/bc52ef94d0ed6b53576cc63b8169576a.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.92
# Processed video bc52ef94d0ed6b53576cc63b8169576a in 0.48 seconds. Remaining: 46 videos.
# Processing video 154/199: /home/user1/hak/video/test_tag_video (2)/videos/7c3fe66284c48634f33b7a3cfb7cb6ec.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.88
# Processed video 7c3fe66284c48634f33b7a3cfb7cb6ec in 0.47 seconds. Remaining: 45 videos.
# Processing video 155/199: /home/user1/hak/video/test_tag_video (2)/videos/7c4056168a7ae581ad60aee08f64cf17.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.57
# Processed video 7c4056168a7ae581ad60aee08f64cf17 in 0.47 seconds. Remaining: 44 videos.
# Processing video 156/199: /home/user1/hak/video/test_tag_video (2)/videos/ac7530ef9a68ae9ca8eaba4d2abbe3aa.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.92
# Processed video ac7530ef9a68ae9ca8eaba4d2abbe3aa in 0.48 seconds. Remaining: 43 videos.
# Processing video 157/199: /home/user1/hak/video/test_tag_video (2)/videos/4c82ef411fc1e7ab07321605c4917b58.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.62
# Processed video 4c82ef411fc1e7ab07321605c4917b58 in 0.47 seconds. Remaining: 42 videos.
# Processing video 158/199: /home/user1/hak/video/test_tag_video (2)/videos/1c8af4543c345fd937bdc234a72712f1.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.77
# Processed video 1c8af4543c345fd937bdc234a72712f1 in 0.48 seconds. Remaining: 41 videos.
# Processing video 159/199: /home/user1/hak/video/test_tag_video (2)/videos/6c636035fe69c7eece985a4fd98d1989.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.35
# Processed video 6c636035fe69c7eece985a4fd98d1989 in 0.48 seconds. Remaining: 40 videos.
# Processing video 160/199: /home/user1/hak/video/test_tag_video (2)/videos/0caf7c166b36608e0bad7aa8512af366.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.91
# Processed video 0caf7c166b36608e0bad7aa8512af366 in 0.47 seconds. Remaining: 39 videos.
# Processing video 161/199: /home/user1/hak/video/test_tag_video (2)/videos/cd08a80aae2b212a987cba6e9207e6ab.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.23
# Processed video cd08a80aae2b212a987cba6e9207e6ab in 0.48 seconds. Remaining: 38 videos.
# Processing video 162/199: /home/user1/hak/video/test_tag_video (2)/videos/4cb8085a4154b91c5e6288c33b70949c.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.74
# Processed video 4cb8085a4154b91c5e6288c33b70949c in 0.48 seconds. Remaining: 37 videos.
# Processing video 163/199: /home/user1/hak/video/test_tag_video (2)/videos/2c745419906a934efc4201da29f31c3b.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.59
# Processed video 2c745419906a934efc4201da29f31c3b in 0.48 seconds. Remaining: 36 videos.
# Processing video 164/199: /home/user1/hak/video/test_tag_video (2)/videos/cd1022c69c974065880ba726fae24077.mp4
# Наиболее уверенные теги и их точность:
# Processed video cd1022c69c974065880ba726fae24077 in 0.47 seconds. Remaining: 35 videos.
# Processing video 165/199: /home/user1/hak/video/test_tag_video (2)/videos/cd25c8d9c603817d3dd263e61c5132c4.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.16
# Processed video cd25c8d9c603817d3dd263e61c5132c4 in 0.47 seconds. Remaining: 34 videos.
# Processing video 166/199: /home/user1/hak/video/test_tag_video (2)/videos/dd5057dd0fdd79ca5e699a5502a4b76f.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.61
# Processed video dd5057dd0fdd79ca5e699a5502a4b76f in 0.47 seconds. Remaining: 33 videos.
# Processing video 167/199: /home/user1/hak/video/test_tag_video (2)/videos/2caa27c4926768a14395b856a7cfa580.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.91
# Processed video 2caa27c4926768a14395b856a7cfa580 in 0.47 seconds. Remaining: 32 videos.
# Processing video 168/199: /home/user1/hak/video/test_tag_video (2)/videos/4d03cff18447ff0e57785eedfea2c0d0.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.86
# Processed video 4d03cff18447ff0e57785eedfea2c0d0 in 0.47 seconds. Remaining: 31 videos.
# Processing video 169/199: /home/user1/hak/video/test_tag_video (2)/videos/6cd9c85028c3e584b6d85c85350e2d2e.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.37
# Processed video 6cd9c85028c3e584b6d85c85350e2d2e in 0.46 seconds. Remaining: 30 videos.
# Processing video 170/199: /home/user1/hak/video/test_tag_video (2)/videos/cd5698491064bcad3ab1347aba398846.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.83
# Processed video cd5698491064bcad3ab1347aba398846 in 0.47 seconds. Remaining: 29 videos.
# Processing video 171/199: /home/user1/hak/video/test_tag_video (2)/videos/fcb009f177116d100e67f88f57006190.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.78
# Processed video fcb009f177116d100e67f88f57006190 in 0.47 seconds. Remaining: 28 videos.
# Processing video 172/199: /home/user1/hak/video/test_tag_video (2)/videos/3d1a29fec21eeb0a483a12d7295ecc50.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.85
# Processed video 3d1a29fec21eeb0a483a12d7295ecc50 in 0.47 seconds. Remaining: 27 videos.
# Processing video 173/199: /home/user1/hak/video/test_tag_video (2)/videos/1d44aeebed05f8e40cbcdda99a4447c2.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.91
# Processed video 1d44aeebed05f8e40cbcdda99a4447c2 in 0.47 seconds. Remaining: 26 videos.
# Processing video 174/199: /home/user1/hak/video/test_tag_video (2)/videos/3d5228b11649c452afc7984575d17673.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.86
# Processed video 3d5228b11649c452afc7984575d17673 in 0.47 seconds. Remaining: 25 videos.
# Processing video 175/199: /home/user1/hak/video/test_tag_video (2)/videos/7d6f46570858201ff82cb95e8b12d17a.mp4
# Наиболее уверенные теги и их точность:
# Дом и сад: Дизайн интерьера: 0.16
# Processed video 7d6f46570858201ff82cb95e8b12d17a in 0.48 seconds. Remaining: 24 videos.
# Processing video 176/199: /home/user1/hak/video/test_tag_video (2)/videos/fd197fedd8504e4925331419570585c2.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video fd197fedd8504e4925331419570585c2 in 0.47 seconds. Remaining: 23 videos.
# Processing video 177/199: /home/user1/hak/video/test_tag_video (2)/videos/cdbfc46415b63955159836a012fd1ca3.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.76
# Processed video cdbfc46415b63955159836a012fd1ca3 in 0.47 seconds. Remaining: 22 videos.
# Processing video 178/199: /home/user1/hak/video/test_tag_video (2)/videos/4dbf1e5781face4cfadef43ca2805ce6.mp4
# Наиболее уверенные теги и их точность:
# Processed video 4dbf1e5781face4cfadef43ca2805ce6 in 0.47 seconds. Remaining: 21 videos.
# Processing video 179/199: /home/user1/hak/video/test_tag_video (2)/videos/3db4105224b495121c7e1e8ad73c407d.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.21
# Processed video 3db4105224b495121c7e1e8ad73c407d in 0.48 seconds. Remaining: 20 videos.
# Processing video 180/199: /home/user1/hak/video/test_tag_video (2)/videos/5ddd14aa6e5928bb215b9ed1b073af91.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.54
# Processed video 5ddd14aa6e5928bb215b9ed1b073af91 in 0.47 seconds. Remaining: 19 videos.
# Processing video 181/199: /home/user1/hak/video/test_tag_video (2)/videos/1ddd99371b693e452499236b87ebb925.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.92
# Processed video 1ddd99371b693e452499236b87ebb925 in 0.47 seconds. Remaining: 18 videos.
# Processing video 182/199: /home/user1/hak/video/test_tag_video (2)/videos/ae1aabff40cc1ca65387bcb4e8506b08.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.75
# Processed video ae1aabff40cc1ca65387bcb4e8506b08 in 0.48 seconds. Remaining: 17 videos.
# Processing video 183/199: /home/user1/hak/video/test_tag_video (2)/videos/ae5022a0264f784b2aac6de84f1d7569.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video ae5022a0264f784b2aac6de84f1d7569 in 0.47 seconds. Remaining: 16 videos.
# Processing video 184/199: /home/user1/hak/video/test_tag_video (2)/videos/9e97c1d0cb041563a2cb2126aca2e33f.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.29
# Массовая культура: Юмор и сатира: 0.28
# Processed video 9e97c1d0cb041563a2cb2126aca2e33f in 0.47 seconds. Remaining: 15 videos.
# Processing video 185/199: /home/user1/hak/video/test_tag_video (2)/videos/1e52e85eb0ddd2426314271198997729.mp4
# Наиболее уверенные теги и их точность:
# Еда и напитки: Кулинария: 0.34
# Processed video 1e52e85eb0ddd2426314271198997729 in 0.48 seconds. Remaining: 14 videos.
# Processing video 186/199: /home/user1/hak/video/test_tag_video (2)/videos/5ecb04cb42d403172b62c11526a8b3e9.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.59
# Processed video 5ecb04cb42d403172b62c11526a8b3e9 in 0.47 seconds. Remaining: 13 videos.
# Processing video 187/199: /home/user1/hak/video/test_tag_video (2)/videos/6eaa1f88d2e057da110b9679fd05d4f9.mp4
# Наиболее уверенные теги и их точность:
# Религия и духовность: астрология: 0.74
# Processed video 6eaa1f88d2e057da110b9679fd05d4f9 in 0.48 seconds. Remaining: 12 videos.
# Processing video 188/199: /home/user1/hak/video/test_tag_video (2)/videos/eeabf7b51a30979cbbeaf9f6ed05af25.mp4
# Наиболее уверенные теги и их точность:
# Processed video eeabf7b51a30979cbbeaf9f6ed05af25 in 0.47 seconds. Remaining: 11 videos.
# Processing video 189/199: /home/user1/hak/video/test_tag_video (2)/videos/df289788661c5d273a08a8a6cefd03b3.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video df289788661c5d273a08a8a6cefd03b3 in 0.47 seconds. Remaining: 10 videos.
# Processing video 190/199: /home/user1/hak/video/test_tag_video (2)/videos/eeed2eadea117c2cbbaa0ba121a69eac.mp4
# Наиболее уверенные теги и их точность:
# Путешествия: 0.18
# Processed video eeed2eadea117c2cbbaa0ba121a69eac in 0.47 seconds. Remaining: 9 videos.
# Processing video 191/199: /home/user1/hak/video/test_tag_video (2)/videos/8f2338b5cac010765360fe797348b845.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.57
# Processed video 8f2338b5cac010765360fe797348b845 in 0.47 seconds. Remaining: 8 videos.
# Processing video 192/199: /home/user1/hak/video/test_tag_video (2)/videos/4f1bae1f60a3d023acbea0364c481a2f.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video 4f1bae1f60a3d023acbea0364c481a2f in 0.46 seconds. Remaining: 7 videos.
# Processing video 193/199: /home/user1/hak/video/test_tag_video (2)/videos/1f1f054ce2cb4df58b2f1473f979fa25.mp4
# Наиболее уверенные теги и их точность:
# Фильмы и анимация: Семейные и детские фильмы: 0.11
# Processed video 1f1f054ce2cb4df58b2f1473f979fa25 in 0.47 seconds. Remaining: 6 videos.
# Processing video 194/199: /home/user1/hak/video/test_tag_video (2)/videos/4f511d46431db5b97c5f3be075bac5a0.mp4
# Наиболее уверенные теги и их точность:
# Дом и сад: Дизайн интерьера: 0.17
# Processed video 4f511d46431db5b97c5f3be075bac5a0 in 0.47 seconds. Remaining: 5 videos.
# Processing video 195/199: /home/user1/hak/video/test_tag_video (2)/videos/0f84219f46782fca9482fb88da146ed3.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video 0f84219f46782fca9482fb88da146ed3 in 0.47 seconds. Remaining: 4 videos.
# Processing video 196/199: /home/user1/hak/video/test_tag_video (2)/videos/2f67917a65dd8d5b348de81d15b1d8ff.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video 2f67917a65dd8d5b348de81d15b1d8ff in 0.46 seconds. Remaining: 3 videos.
# Processing video 197/199: /home/user1/hak/video/test_tag_video (2)/videos/6fa39a883591bc0e2cf7ef6c5349c9df.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.93
# Processed video 6fa39a883591bc0e2cf7ef6c5349c9df in 0.46 seconds. Remaining: 2 videos.
# Processing video 198/199: /home/user1/hak/video/test_tag_video (2)/videos/bff493ac045715566a86cd7e84051938.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: Юмор и сатира: 0.88
# Processed video bff493ac045715566a86cd7e84051938 in 0.46 seconds. Remaining: 1 videos.
# Processing video 199/199: /home/user1/hak/video/test_tag_video (2)/videos/7fdc692721faaaa5cd74f99b361cf593.mp4
# Наиболее уверенные теги и их точность:
# Массовая культура: 0.32
# Массовая культура: Юмор и сатира: 0.16
# Processed video 7fdc692721faaaa5cd74f99b361cf593 in 0.47 seconds. Remaining: 0 videos.
